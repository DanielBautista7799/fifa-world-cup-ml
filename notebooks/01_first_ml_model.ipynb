# %%
import numpy as np 
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
rating_difference = np.array([
    -200,
    -150,
    -100,
    -50,
    0,
    50,
    100,
    150,
    200,
])

goal_difference = np.array([
    -3,
    -2,
    -1,
    -1,
    0,
    1,
    1,
    2,
    3,
])

# %%
plt.scatter(rating_difference,goal_difference)
plt.xlabel("Rating Difference")
plt.ylabel("Goal Difference")
plt.title("Rating difference vs goal difference")
plt.show()

# %%
weight = 0.0
bias = 0.0
prediciton = weight * rating_difference + bias
print(prediciton)

errors = goal_difference - prediciton
squared_errors = (errors)**2
Mean_Squared_Error = np.mean(squared_errors)
print(errors)
print(squared_errors)
print(Mean_Squared_Error)
# Out:
# [0. 0. 0. 0. 0. 0. 0. 0. 0.]
